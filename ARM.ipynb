# %%
library(arules)
basket_df <- read.csv('data/basket_df_all.csv')
basket_df_pos <- read.transactions('data/basket_pos.csv',format='b',header=TRUE)
basket_df_neg <- read.transactions('data/basket_neg.csv',format='b',header=TRUE)

# %%
inspect(basket_df_neg)
# Out:
#      items
# [1]  {bad,
#       bow,
#       company,
#       ha,
#       half,
#       having,
#       help,
#       hope,
#       just,
#       look,
#       maybe,
#       package,
#       people,
#       purchase,
#       string,
#       thank,
#       thought,
#       tried,
#       twist,
#       wa,
#       way,
#       worth}
# [2]  {accessory,
#       arrow,
#       beat,
#       better,
#       bow,
#       button,
#       came,
#       cheap,
#       come,
#       compound,
#       contact,
#       did,
#       far,
#       felt,
#       giving,
#       groove,
#       ha,
#       just,
#       keeping,
#       light,
#       like,
#       limb,
#       lower,
#       really,
#       recurve,
#       rest,
#       returning,
#       seller,
#       slightly,
#       stabilizer,
#       star,
#       string,
#       tell,
#       tried,
#       twisted,
#       twisting,
#       use,
#       wa,
#       wanted,
#       way,
#       work}
# [3]  {accurate,
#       arrow,
# ...

# %%
FirstRule <- arules::apriori(basket_df_pos, parameter = list(support=0.4,
                                                    confidence =0.7,
                                                    minlen=2))
inspect(FirstRule)
# Out:
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.7    0.1    1 none FALSE            TRUE       5     0.4      2
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 6
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[265 item(s), 15 transaction(s)] done [0.00s].
# sorting and recoding items ... [28 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [960 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
#       lhs                                       rhs        support   confidence
# [1]   {need}                                 => {arrow}    0.4000000 1.0000000
# [2]   {need}                                 => {bow}      0.4000000 1.0000000
# ...

# %%
SortedRules <- sort(FirstRule, by="lift", decreasing=TRUE)
inspect(SortedRules[1:100])
# Out:
#       lhs                                      rhs        support   confidence
# [1]   {just, like}                          => {review}   0.4000000 1.0000000
# [2]   {arrow, just, like}                   => {review}   0.4000000 1.0000000
# [3]   {bow, just, like}                     => {review}   0.4000000 1.0000000
# [4]   {arrow, bow, just, like}              => {review}   0.4000000 1.0000000
# [5]   {review}                              => {like}     0.4000000 1.0000000
# [6]   {like}                                => {review}   0.4000000 0.8571429
# [7]   {just, review}                        => {like}     0.4000000 1.0000000
# [8]   {arrow, review}                       => {like}     0.4000000 1.0000000
# [9]   {arrow, like}                         => {review}   0.4000000 0.8571429
# [10]  {bow, review}                         => {like}     0.4000000 1.0000000
# [11]  {bow, like}                           => {review}   0.4000000 0.8571429
# ...

# %%
SecondRule <- arules::apriori(basket_df_neg, parameter = list(support=0.2,
                                                    confidence =0.5,
                                                    minlen=2))
# Out:
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.5    0.1    1 none FALSE            TRUE       5     0.2      2
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 3
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[174 item(s), 15 transaction(s)] done [0.00s].
# sorting and recoding items ... [24 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [150 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].

# %%
SortedRules2 <- sort(SecondRule, by="lift", decreasing=TRUE)
inspect(SortedRules2[1:100])
# Out:
#       lhs                     rhs       support   confidence coverage  lift
# [1]   {just}               => {wa}      0.2000000 1.0000000  0.2000000 3.750000
# [2]   {wa}                 => {just}    0.2000000 0.7500000  0.2666667 3.750000
# [3]   {just, string}       => {wa}      0.2000000 1.0000000  0.2000000 3.750000
# [4]   {string, wa}         => {just}    0.2000000 0.7500000  0.2666667 3.750000
# [5]   {arrow, better}      => {rest}    0.2000000 0.7500000  0.2666667 3.750000
# [6]   {bow, wa}            => {way}     0.2000000 1.0000000  0.2000000 3.750000
# [7]   {arrow, bow, limb}   => {lower}   0.2000000 0.7500000  0.2666667 3.750000
# [8]   {bow, string, wa}    => {way}     0.2000000 1.0000000  0.2000000 3.750000
# [9]   {rest}               => {better}  0.2000000 1.0000000  0.2000000 3.000000
# [10]  {better}             => {rest}    0.2000000 0.6000000  0.3333333 3.000000
# [11]  {arrow, limb}        => {lower}   0.2000000 0.6000000  0.3333333 3.000000
# ...
